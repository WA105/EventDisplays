# %%
from swiss_highway_mc6_functions import *
subrun = 0
event = 52
track = 0
colorscale_range = [0, 20]
savefig = False
event_display(6, subrun, event, colorscale_range, savefig=savefig)
# Out:
#   File "swiss_highway_mc6_functions.py", line 142
#
#     ^
# SyntaxError: invalid syntax

# %%
from swiss_highway_mc6_functions import *
# Out:
# Welcome to JupyROOT 6.12/06

# %%
from swiss_highway_mc6_functions import *
subrun = 0
event = 53
track = 0
colorscale_range = [0, 20]
savefig = False
event_display(6, subrun, event, colorscale_range, savefig=savefig)

# %%
from mc_evt_display_functions import *
subrun = 0
event = 25
track = 0
colorscale_range = [0, 20]
savefig = False
event_display(6, subrun, event, colorscale_range, savefig=savefig)
# Out:
# ----------------
